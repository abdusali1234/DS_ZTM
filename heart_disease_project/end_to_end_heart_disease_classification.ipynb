# %% [markdown]
# # Predicting heart disease using machine learning
#
# This notebook looks at using various python ML and DS science libraries to build an ML model capable of detecting whether a patient has heart disease based on their medical attributes.
#
# The following approach will be taken:
# 1. Problem definition
# 2. Data
# 3. Evaluation
# 4. Features
# 5. Modelling
# 6. Experimentation

# %% [markdown]
# ## 1. Problem definition
#
# > Given clinical parameters about a patient, can we predict if that patient has heart disease?
#
# ## 2. Data
#         age
#         sex
#         chest pain type (4 values)
#         resting blood pressure
#         serum cholestoral in mg/dl
#         fasting blood sugar > 120 mg/dl
#         resting electrocardiographic results (values 0,1,2)
#         maximum heart rate achieved
#         exercise induced angina
#         oldpeak = ST depression induced by exercise relative to rest
#         the slope of the peak exercise ST segment
#         number of major vessels (0-3) colored by flourosopy
#         thal: 0 = normal; 1 = fixed defect; 2 = reversable defect
#         The names and social security numbers of the patients were recently removed from the database, replaced with dummy values.
#
# ## 3. Evaluation
#
# > If we can reach 95% accuracy predicting whether or not a patient has heart disease durring PoC, we'll pursue the project.
#
# ## 4. Features

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV, GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, RocCurveDisplay

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv("heart-disease.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# ## EDA

# %%
df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
# NO. members in each class
df["target"].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
# check for missing values
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %% [markdown]
# ### Heart disease according to sex

# %%
df['sex'].value_counts()
# Out:
# 1    207
# 0     96
# Name: sex, dtype: int64

# %%
    heart_disease_freq_by_sex = pd.crosstab(df['target'],df['sex'])
heart_disease_freq_by_sex
# Out:
# sex      0    1
# target
# 0       24  114
# 1       72   93

# %%
heart_disease_freq_by_sex.plot(kind='bar', figsize=(10,6), color=["salmon", "lightblue"])
plt.title("Heart disease frequency by sex")
plt.xlabel("0= no disease, 1= heart disease")
plt.ylabel("Frequency")
plt.legend(["Female", "Male"])
plt.xticks(rotation=0)
# Out:
# (array([0, 1]), [Text(0, 0, '0'), Text(1, 0, '1')])

# %%
# Age vs max heart rate

# scatter with positive examples (has heart disease)
plt.figure(figsize=(10,6))
plt.scatter(df['age'][df['target']==1],df['thalach'][df['target']==1], c='salmon' )

# scatter with negative examples (no HD)
plt.scatter(df['age'][df['target']==0],df['thalach'][df['target']==0], c='lightblue' )
plt.xlabel('Age')
plt.ylabel('Max heart rate')
plt.legend(['Disease', 'No disease'])

# %%
#check distribution of age with a histogram
df['age'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### HD frequency vs chest pain type

# %%
heart_disease_by_pain_type = pd.crosstab(df['cp'], df['target'])
heart_disease_by_pain_type
# Out:
# target    0   1
# cp
# 0       104  39
# 1         9  41
# 2        18  69
# 3         7  16

# %%
heart_disease_by_pain_type.plot(kind="bar", figsize=(10,6), color=["salmon", "lightblue"])
plt.xlabel('Chest pain type')
plt.ylabel('Amount')
plt.legend(['No disease', 'Disease'])
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, '0'), Text(1, 0, '1'), Text(2, 0, '2'), Text(3, 0, '3')])

# %%
# correlation matrix
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# /tmp/ipykernel_1559/459550279.py:3: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_dd2db_row0_col0, #T_dd2db_row1_col1, #T_dd2db_row2_col2, #T_dd2db_row3_col3, #T_dd2db_row4_col4, #T_dd2db_row5_col5, #T_dd2db_row6_col6, #T_dd2db_row7_col7, #T_dd2db_row8_col8, #T_dd2db_row9_col9, #T_dd2db_row10_col10, #T_dd2db_row11_col11, #T_dd2db_row12_col12, #T_dd2db_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_dd2db_row0_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_dd2db_row0_col2, #T_dd2db_row4_col3, #T_dd2db_row5_col12 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_dd2db_row0_col3, #T_dd2db_row5_col9, #T_dd2db_row10_col2, #T_dd2db_row11_col12 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_dd2db_row0_col4 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_dd2db_row0_col5 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_dd2db_row0_col6, #T_dd2db_row2_col8 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_dd2db_row0_col7, #T_dd2db_row1_col4, #T_dd2db_row4_col6, #T_dd2db_row6_col5, #T_dd2db_row7_col0, #T_dd2db_row8_col2, #T_dd2db_row8_col13, #T_dd2db_row9_col10, #T_dd2db_row10_col9, #T_dd2db_row13_col1, #T_dd2db_row13_col3, #T_dd2db_row13_col8, #T_dd2db_row13_col11, #T_dd2db_row13_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_dd2db_row0_col8, #T_dd2db_row5_col0 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_dd2db_row0_col9, #T_dd2db_row2_col7, #T_dd2db_row12_col9 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_dd2db_row0_col10 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_dd2db_row0_col11 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_dd2db_row0_col12 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_dd2db_row0_col13, #T_dd2db_row7_col9 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_dd2db_row1_col0, #T_dd2db_row10_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_dd2db_row1_col2, #T_dd2db_row6_col12, #T_dd2db_row12_col4 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_dd2db_row1_col3 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_dd2db_row1_col5, #T_dd2db_row12_col6 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_dd2db_row1_col6, #T_dd2db_row9_col6 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_dd2db_row1_col7, #T_dd2db_row3_col7, #T_dd2db_row13_col6 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_dd2db_row1_col8 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_dd2db_row1_col9 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_dd2db_row1_col10 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_dd2db_row1_col11, #T_dd2db_row4_col10, #T_dd2db_row8_col11 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_dd2db_row1_col12, #T_dd2db_row9_col12 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_dd2db_row1_col13 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_dd2db_row2_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_dd2db_row2_col1, #T_dd2db_row12_col3 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_dd2db_row2_col3, #T_dd2db_row2_col6, #T_dd2db_row7_col6 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_dd2db_row2_col4, #T_dd2db_row8_col5 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_dd2db_row2_col5, #T_dd2db_row10_col0, #T_dd2db_row12_col2 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_dd2db_row2_col9 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_dd2db_row2_col10, #T_dd2db_row9_col11 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_dd2db_row2_col11 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_dd2db_row2_col12 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_dd2db_row2_col13 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_dd2db_row3_col0 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_dd2db_row3_col1, #T_dd2db_row6_col1, #T_dd2db_row9_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_dd2db_row3_col2, #T_dd2db_row6_col7 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_dd2db_row3_col4 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_dd2db_row3_col5 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_dd2db_row3_col6, #T_dd2db_row11_col13 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_dd2db_row3_col8, #T_dd2db_row4_col8, #T_dd2db_row5_col2 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_dd2db_row3_col9 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_dd2db_row3_col10 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_dd2db_row3_col11, #T_dd2db_row8_col0 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_dd2db_row3_col12 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_dd2db_row3_col13, #T_dd2db_row6_col0, #T_dd2db_row8_col10 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_dd2db_row4_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_dd2db_row4_col1, #T_dd2db_row12_col13 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_dd2db_row4_col2, #T_dd2db_row6_col11 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_dd2db_row4_col5, #T_dd2db_row13_col9 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_dd2db_row4_col7, #T_dd2db_row5_col7 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_dd2db_row4_col9, #T_dd2db_row6_col13 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_dd2db_row4_col11, #T_dd2db_row12_col0 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_dd2db_row4_col12, #T_dd2db_row5_col10, #T_dd2db_row6_col9, #T_dd2db_row8_col1 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_dd2db_row4_col13 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_dd2db_row5_col1, #T_dd2db_row6_col8 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_dd2db_row5_col3, #T_dd2db_row5_col13 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_dd2db_row5_col4, #T_dd2db_row10_col12 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_dd2db_row5_col6 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_dd2db_row5_col8 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_dd2db_row5_col11 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_dd2db_row6_col2, #T_dd2db_row11_col10 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_dd2db_row6_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_dd2db_row6_col4, #T_dd2db_row7_col8 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_dd2db_row6_col10 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_dd2db_row7_col1, #T_dd2db_row7_col12, #T_dd2db_row8_col3 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_dd2db_row7_col2 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_dd2db_row7_col3, #T_dd2db_row9_col5 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_dd2db_row7_col4 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_dd2db_row7_col5, #T_dd2db_row8_col6, #T_dd2db_row11_col6 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_dd2db_row7_col10 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_dd2db_row7_col11 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_dd2db_row7_col13, #T_dd2db_row13_col2 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_dd2db_row8_col4 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_dd2db_row8_col7 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_dd2db_row8_col9 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_dd2db_row8_col12 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_dd2db_row9_col0 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_dd2db_row9_col1, #T_dd2db_row9_col3 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_dd2db_row9_col4 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_dd2db_row9_col7 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_dd2db_row9_col8, #T_dd2db_row11_col9 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_dd2db_row9_col13 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_dd2db_row10_col1 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_dd2db_row10_col3, #T_dd2db_row10_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_dd2db_row10_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_dd2db_row10_col7 {
#   backgrou

# %% [markdown]
# ## Modelling

# %%
# A reminder of what the data looks like
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#split data into X & y
X = df.drop('target', axis=1)
y = df['target']

# %%
X
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# 3        2   0     2
# 4        2   0     2
# ..     ...  ..   ...
# 298      1   0     3
# 299      1   0     3
# 300      1   2     3
# 301      1   1     3
# 302      1   1     2
#
# [303 rows x 13 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
# split data into train and test sets

np.random.seed(42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 132   42    1   1       120   295    0        1      162      0      0.0
# 202   58    1   0       150   270    0        0      111      1      0.8
# 196   46    1   2       150   231    0        1      147      0      3.6
# 75    55    0   1       135   250    0        0      161      0      1.4
# 176   60    1   0       117   230    1        1      160      1      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 188   50    1   2       140   233    0        1      163      0      0.6
# 71    51    1   2        94   227    0        1      154      1      0.0
# 106   69    1   3       160   234    1        0      131      0      0.1
# 270   46    1   0       120   249    0        0      144      0      0.8
# 102   63    0   1       140   195    0        1      179      0      0.0
#
#      slope  ca  thal
# 132      2   0     2
# 202      2   0     3
# 196      1   0     2
# 75       1   0     2
# 176      2   2     3
# ..     ...  ..   ...
# 188      1   1     3
# 71       2   1     3
# 106      1   1     2
# 270      2   0     3
# 102      2   2     2
#
# [242 rows x 13 columns]

# %%
y_train
# Out:
# 132    1
# 202    0
# 196    0
# 75     1
# 176    0
#       ..
# 188    0
# 71     1
# 106    1
# 270    0
# 102    1
# Name: target, Length: 242, dtype: int64

# %% [markdown]
# Time to train some models on the training set, and evaluate them on the test set to see which model performs the best
